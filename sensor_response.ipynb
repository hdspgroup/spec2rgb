# %%
from spec2rgb import ColourSystem
import matplotlib.pyplot as plt 


def plot_response(M, cs):
    plt.title(f"RGB response - {cs}")
    plt.plot(RGB[:,0], c='r')
    plt.plot(RGB[:,1], c='g')
    plt.plot(RGB[:,2], c='b')
    plt.show()

# %%
color_space = "CIERGB"
cs_ciergb = ColourSystem(cs=color_space, start=380, end=750, num=310)
RGB = cs_ciergb.get_transform_matrix()
plot_response(RGB, color_space)

# %%
color_space = "sRGB"
cs_ciergb = ColourSystem(cs=color_space, start=380, end=750, num=310)
RGB = cs_ciergb.get_transform_matrix()
plot_response(RGB, color_space)
